# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
def plot_promoter_activity_correlation(activity_df, title, ax):
    pearsonr, _ = stats.pearsonr(activity_df['mean'], activity_df['H3K27ac.RPM.TSS1Kb'])
    sns.scatterplot(data=activity_df, x='mean', y='H3K27ac.RPM.TSS1Kb', alpha=0.5, ax=ax)
    sns.regplot(data=activity_df, x='mean', y='H3K27ac.RPM.TSS1Kb', scatter=False, color='red', label=f'Pearson r={pearsonr:.2f}', ax=ax)
    ax.set_xlabel('IHEC H3K27ac Mean')
    ax.set_ylabel('ENCODE H3K27ac')
    ax.set_title(title)
    ax.legend()

# %% [markdown]
# # Promoter activity

# %%
orig_activity_k562 = pd.read_csv('data/K562_DNase_ENCFF257HEE_hic_4DNFITUOMFUQ_1MB_ABC_nominated/DNase_ENCFF257HEE_Neighborhoods/GeneList.txt', sep='\t')
orig_activity_gm12878 = pd.read_csv('data/GM12878_DNase_ENCFF020WZB_hic_4DNFI1UEG1HD_1MB_ABC_nominated/DNase_ENCFF020WZB_Neighborhoods/GeneList.txt', sep='\t')
orig_activity_k562
# Out:
#          chr      start        end             name  score strand  \
# 0       chrX  100625428  100636750  ENSG00000000003      0      -
# 1       chrX  100584935  100600019  ENSG00000000005      0      +
# 2      chr20   50934842   50958531  ENSG00000000419      0      -
# 3       chr1  169849258  169893895  ENSG00000000457      0      -
# 4       chr1  169795044  169987021  ENSG00000000460      0      +
# ...      ...        ...        ...              ...    ...    ...
# 18372  chr20   36574515   36612347  ENSG00000259399      0      +
# 18373  chr14   23556270   23560535  ENSG00000259431      0      +
# 18374  chr15   84172490   84182235  ENSG00000259511      0      +
# 18375  chr11  122115353  122116215  ENSG00000259571      0      -
# 18376  chr16   33844576   33845229  ENSG00000259680      0      -
#
#                 symbol        tss  Expression cellType  ...  \
# 0      ENSG00000000003  100636750         NaN     K562  ...
# 1      ENSG00000000005  100584935         NaN     K562  ...
# 2      ENSG00000000419   50958531         NaN     K562  ...
# 3      ENSG00000000457  169893895         NaN     K562  ...
# 4      ENSG00000000460  169795044         NaN     K562  ...
# ...                ...        ...         ...      ...  ...
# 18372  ENSG00000259399   36574515         NaN     K562  ...
# 18373  ENSG00000259431   23556270         NaN     K562  ...
# 18374  ENSG00000259511   84172490         NaN     K562  ...
# 18375  ENSG00000259571  122116215         NaN     K562  ...
# 18376  ENSG00000259680   33845229         NaN     K562  ...
#
#        DHS.ENCFF257HEE.bam.RPM.TSS1Kb  \
# 0                            0.600308
# 1                            0.176740
# 2                            6.850214
# 3                           20.270295
# 4                            9.900509
# ...                               ...
# 18372                        5.366204
# 18373                        6.201150
# 18374                        0.466229
# 18375                        0.234638
# 18376                        0.176740
#
#        DHS.ENCFF257HEE.bam.readCount.quantile.TSS1Kb  \
# 0                                           0.222207
# 1                                           0.043995
# 2                                           0.597785
# 3                                           0.950482
# 4                                           0.729281
# ...                                              ...
# 18372                                       0.531779
# 18373                                       0.568428
# 18374                                       0.169995
# 18375                                       0.066823
# 18376                                       0.043995
#
#        DHS.ENCFF257HEE.bam.RPM.quantile.TSS1Kb  \
# 0                                     0.222207
# 1                                     0.043995
# 2                                     0.597785
# 3                                     0.950482
# 4                                     0.729281
# ...                                        ...
# 18372                                 0.531779
# 18373                                 0.568428
# 18374                                 0.169995
# 18375                                 0.066823
# 18376                                 0.043995
#
#        DHS.ENCFF257HEE.bam.RPKM.TSS1Kb  \
# 0                             0.600308
# 1                             0.176740
# 2                             6.850214
# 3                            20.270295
# 4                             9.900509
# ...                                ...
# 18372                         5.366204
# 18373                         6.201150
# 18374                         0.466229
# 18375                         0.234638
# 18376                         0.176740
#
#        DHS.ENCFF257HEE.bam.RPKM.quantile.TSS1Kb  DHS.RPM.TSS1Kb  \
# 0                                      0.222207        0.600308
# 1                                      0.043995        0.176740
# 2                                      0.597785        6.850214
# 3                                      0.950482       20.270295
# 4                                      0.729281        9.900509
# ...                                         ...             ...
# 18372                                  0.531779        5.366204
# 18373                                  0.568428        6.201150
# 18374                                  0.169995        0.466229
# 18375                                  0.066823        0.234638
# 18376                                  0.043995        0.176740
#
#        DHS.RPM.quantile.TSS1Kb  DHS.RPKM.TSS1Kb  DHS.RPKM.quantile.TSS1Kb  \
# 0                     0.222207         0.600308                  0.222207
# 1                     0.043995         0.176740                  0.043995
# 2                     0.597785         6.850214                  0.597785
# 3                     0.950482        20.270295                  0.950482
# 4                     0.729281         9.900509                  0.729281
# ...                        ...              ...                       ...
# 18372                 0.531779         5.366204                  0.531779
# 18373                 0.568428         6.201150                  0.568428
# 18374                 0.169995         0.466229                  0.169995
# 18375                 0.066823         0.234638                  0.066823
# 18376                 0.043995         0.176740                  0.043995
#
#        PromoterActivityQuantile
# 0                      0.248245
# 1                      0.039805
# 2                      0.791478
# 3                      0.993198
# 4                      0.887849
# ...                         ...
# 18372                  0.559776
# 18373                  0.602275
# 18374                  0.288186
# 18375                  0.057599
# 18376                  0.034282
#
# [18377 rows x 75 columns]

# %%
ihec_activity_k562 = pd.read_csv('data/IHEC-ChIP-Seq-Histone-Signals/PromotersK562.H3K27ac.tab', sep='\t', names=['gene_id', 'size', 'covered', 'sum', 'mean0', 'mean'])
ihec_activity_gm12878 = pd.read_csv('data/IHEC-ChIP-Seq-Histone-Signals/PromotersGM12878.H3K27ac.tab', sep='\t', names=['gene_id', 'size', 'covered', 'sum', 'mean0', 'mean'])
ihec_activity_k562
# Out:
#                gene_id  size  covered        sum      mean0       mean
# 0      ENSG00000186092  1000     1000      0.000   0.000000   0.000000
# 1      ENSG00000187634  1000     1000    122.686   0.122686   0.122686
# 2      ENSG00000188976  1000     1000   7424.410   7.424410   7.424410
# 3      ENSG00000187961  1000     1000   5172.200   5.172200   5.172200
# 4      ENSG00000187583  1000     1000   5719.150   5.719150   5.719150
# ...                ...   ...      ...        ...        ...        ...
# 18372  ENSG00000155962  1000     1000   8528.710   8.528710   8.528710
# 18373  ENSG00000168939  1000     1000  25763.000  25.763000  25.763000
# 18374  ENSG00000185973  1000     1000  26074.200  26.074200  26.074200
# 18375  ENSG00000124333  1000     1000  19404.800  19.404800  19.404800
# 18376  ENSG00000124334  1000     1000   2860.300   2.860300   2.860300
#
# [18377 rows x 6 columns]

# %%
# count how often something other than 1000 appears in the covered column
non_1000_count = (ihec_activity_k562['covered'] != 1000).sum()
non_1000_count_gm12878 = (ihec_activity_gm12878['covered'] != 1000).sum()
print(f"Number of entries with 'covered' not equal to 1000: {non_1000_count}")
print(f"Number of entries with 'covered' not equal to 1000 (GM12878): {non_1000_count_gm12878}")
# Out:
# Number of entries with 'covered' not equal to 1000: 1
# Number of entries with 'covered' not equal to 1000 (GM12878): 2

# %%
ihec_activity_k562 = ihec_activity_k562.merge(orig_activity_k562[['symbol', 'H3K27ac.RPM.TSS1Kb']], left_on='gene_id', right_on='symbol', how='left')
ihec_activity_k562 = ihec_activity_k562[['gene_id', 'size', 'covered', 'mean0', 'mean', 'H3K27ac.RPM.TSS1Kb']]

# %%
ihec_activity_k562
# Out:
#                gene_id  size  covered      mean0       mean  \
# 0      ENSG00000186092  1000     1000   0.000000   0.000000
# 1      ENSG00000187634  1000     1000   0.122686   0.122686
# 2      ENSG00000188976  1000     1000   7.424410   7.424410
# 3      ENSG00000187961  1000     1000   5.172200   5.172200
# 4      ENSG00000187583  1000     1000   5.719150   5.719150
# ...                ...   ...      ...        ...        ...
# 18372  ENSG00000155962  1000     1000   8.528710   8.528710
# 18373  ENSG00000168939  1000     1000  25.763000  25.763000
# 18374  ENSG00000185973  1000     1000  26.074200  26.074200
# 18375  ENSG00000124333  1000     1000  19.404800  19.404800
# 18376  ENSG00000124334  1000     1000   2.860300   2.860300
#
#        H3K27ac.RPM.TSS1Kb
# 0                0.004714
# 1                0.268734
# 2                4.783962
# 3                2.199607
# 4                3.587233
# ...                   ...
# 18372            8.074045
# 18373           12.016016
# 18374           11.245005
# 18375           13.044522
# 18376            1.439918
#
# [18377 rows x 6 columns]

# %%
ihec_activity_gm12878 = ihec_activity_gm12878.merge(orig_activity_gm12878[['symbol', 'H3K27ac.RPM.TSS1Kb']], left_on='gene_id', right_on='symbol', how='left')
ihec_activity_gm12878 = ihec_activity_gm12878[['gene_id', 'size', 'covered', 'mean0', 'mean', 'H3K27ac.RPM.TSS1Kb']]

# %%
# drop na rows
ihec_activity_k562 = ihec_activity_k562.dropna(subset=['H3K27ac.RPM.TSS1Kb'])
ihec_activity_gm12878 = ihec_activity_gm12878.dropna(subset=['H3K27ac.RPM.TSS1Kb'])

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 6), sharey=True)
plot_promoter_activity_correlation(ihec_activity_k562, 'K562 Promoter Activity Correlation', ax1)
plot_promoter_activity_correlation(ihec_activity_gm12878, 'GM12878 Promoter Activity Correlation', ax2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Check other histone signals

# %%
histone_signals_k562 = pd.read_csv('data/IHEC-ChIP-Seq-Histone-Signals/Promoter_Combined_K562_Histone_Signals.csv', sep=',')
histone_signals_gm12878 = pd.read_csv('data/IHEC-ChIP-Seq-Histone-Signals/Promoter_Combined_GM12878_Histone_Signals.csv', sep=',')
histone_signals_k562
# Out:
#                gene_id  covered  H3K27ac.mean  H3K27me3.mean  H3K36me3.mean  \
# 0      ENSG00000186092     1000      0.000000       0.000000       0.000000
# 1      ENSG00000187634     1000      0.122686       0.620256       0.037355
# 2      ENSG00000188976     1000      7.424410       0.812435       0.584804
# 3      ENSG00000187961     1000      5.172200       0.002291       0.357234
# 4      ENSG00000187583     1000      5.719150       0.451246       0.380420
# ...                ...      ...           ...            ...            ...
# 18372  ENSG00000155962     1000      8.528710       0.054322       0.297257
# 18373  ENSG00000168939     1000     25.763000       0.125218       0.404569
# 18374  ENSG00000185973     1000     26.074200       0.134628       0.324383
# 18375  ENSG00000124333     1000     19.404800       0.232984       0.411508
# 18376  ENSG00000124334     1000      2.860300       0.218578       0.094750
#
#        H3K4me1.mean  H3K4me3.mean  H3K9me3.mean
# 0          0.000000      0.000000      0.000000
# 1         26.322300      3.028900      0.055485
# 2         12.919200     19.222500      0.483096
# 3         15.954900     20.710800      0.280394
# 4         37.801600      7.794600      0.591104
# ...             ...           ...           ...
# 18372      0.485921      5.461430      0.359953
# 18373      2.722380     19.724500      0.513137
# 18374      3.261800     17.967700      0.592924
# 18375      1.019420     11.799200      0.460992
# 18376      2.201750      0.594174      0.592973
#
# [18377 rows x 8 columns]

# %%
# drop rows where covered is not 1000
histone_signals_k562 = histone_signals_k562[histone_signals_k562['covered'] == 1000]
histone_signals_gm12878 = histone_signals_gm12878[histone_signals_gm12878['covered'] == 1000]

# %%
# melt the dataframe to have a signal column and a histone type column
histone_signals_k562_melted = histone_signals_k562.melt(id_vars=['gene_id', 'covered'], var_name='histone_type', value_name='signal')
histone_signals_gm12878_melted = histone_signals_gm12878.melt(id_vars=['gene_id', 'covered'], var_name='histone_type', value_name='signal')
histone_signals_k562_melted
# Out:
#                 gene_id  covered  histone_type    signal
# 0       ENSG00000186092     1000  H3K27ac.mean  0.000000
# 1       ENSG00000187634     1000  H3K27ac.mean  0.122686
# 2       ENSG00000188976     1000  H3K27ac.mean  7.424410
# 3       ENSG00000187961     1000  H3K27ac.mean  5.172200
# 4       ENSG00000187583     1000  H3K27ac.mean  5.719150
# ...                 ...      ...           ...       ...
# 110251  ENSG00000155962     1000  H3K9me3.mean  0.359953
# 110252  ENSG00000168939     1000  H3K9me3.mean  0.513137
# 110253  ENSG00000185973     1000  H3K9me3.mean  0.592924
# 110254  ENSG00000124333     1000  H3K9me3.mean  0.460992
# 110255  ENSG00000124334     1000  H3K9me3.mean  0.592973
#
# [110256 rows x 4 columns]

# %%
# combine the two melted dataframes
histone_signals_k562_melted['cell_type'] = 'K562'
histone_signals_gm12878_melted['cell_type'] = 'GM12878'
histone_signals_melted_combined = pd.concat([histone_signals_k562_melted, histone_signals_gm12878_melted], ignore_index=True)
histone_signals_melted_combined
# Out:
#                 gene_id  covered  histone_type    signal cell_type
# 0       ENSG00000186092     1000  H3K27ac.mean  0.000000      K562
# 1       ENSG00000187634     1000  H3K27ac.mean  0.122686      K562
# 2       ENSG00000188976     1000  H3K27ac.mean  7.424410      K562
# 3       ENSG00000187961     1000  H3K27ac.mean  5.172200      K562
# 4       ENSG00000187583     1000  H3K27ac.mean  5.719150      K562
# ...                 ...      ...           ...       ...       ...
# 220501  ENSG00000155962     1000  H3K9me3.mean  1.489730   GM12878
# 220502  ENSG00000168939     1000  H3K9me3.mean  2.160550   GM12878
# 220503  ENSG00000185973     1000  H3K9me3.mean  2.557530   GM12878
# 220504  ENSG00000124333     1000  H3K9me3.mean  1.486290   GM12878
# 220505  ENSG00000124334     1000  H3K9me3.mean  0.737160   GM12878
#
# [220506 rows x 5 columns]

# %%
# plot box plots for each histone type
plt.figure(figsize=(12, 6))
sns.boxplot(data=histone_signals_melted_combined, x='histone_type', y='signal', log_scale=True, hue='cell_type')
plt.xticks(rotation=0)
plt.title('Histone Signals by Type')
plt.xlabel('Histone Type')
plt.ylabel('Signal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Enhancer activity

# %%
orig_activity_k562 = pd.read_csv('../data/K562_DNase_ENCFF257HEE_hic_4DNFITUOMFUQ_1MB_ABC_nominated/DNase_ENCFF257HEE_Neighborhoods/EnhancerList.txt', sep='\t')
orig_activity_gm12878 = pd.read_csv('../data/GM12878_DNase_ENCFF020WZB_hic_4DNFI1UEG1HD_1MB_ABC_nominated/DNase_ENCFF020WZB_Neighborhoods/EnhancerList.txt', sep='\t')
orig_activity_k562
# Out:
#          chr     start       end  H3K27ac.ENCFF600THN.bam.readCount  \
# 0       chr1    585952    586452                                  0
# 1       chr1    605341    605841                                  6
# 2       chr1    629686    630186                                  2
# 3       chr1    633778    634278                                  5
# 4       chr1    778388    779144                                 69
# ...      ...       ...       ...                                ...
# 116664  chrY  11329663  11330163                                  8
# 116665  chrY  11333773  11334507                                  1
# 116666  chrY  11712120  11712620                                  0
# 116667  chrY  56849825  56850381                                  5
# 116668  chrY  56850826  56851326                                  1
#
#         H3K27ac.ENCFF600THN.bam.RPM  \
# 0                          0.000000
# 1                          0.562383
# 2                          0.187461
# 3                          0.468652
# 4                          6.467401
# ...                             ...
# 116664                     0.749844
# 116665                     0.093730
# 116666                     0.000000
# 116667                     0.468652
# 116668                     0.093730
#
#         H3K27ac.ENCFF600THN.bam.readCount.quantile  \
# 0                                         0.027737
# 1                                         0.485309
# 2                                         0.192759
# 3                                         0.431336
# 4                                         0.876625
# ...                                            ...
# 116664                                    0.561537
# 116665                                    0.100117
# 116666                                    0.027737
# 116667                                    0.431336
# 116668                                    0.100117
#
#         H3K27ac.ENCFF600THN.bam.RPM.quantile  H3K27ac.ENCFF600THN.bam.RPKM  \
# 0                                   0.027737                      0.000000
# 1                                   0.485309                      1.124765
# 2                                   0.192759                      0.374922
# 3                                   0.431336                      0.937304
# 4                                   0.876625                      8.554763
# ...                                      ...                           ...
# 116664                              0.561537                      1.499687
# 116665                              0.100117                      0.127698
# 116666                              0.027737                      0.000000
# 116667                              0.431336                      0.842900
# 116668                              0.100117                      0.187461
#
#         H3K27ac.ENCFF600THN.bam.RPKM.quantile  \
# 0                                    0.027737
# 1                                    0.557479
# 2                                    0.232765
# 3                                    0.503870
# 4                                    0.899073
# ...                                       ...
# 116664                               0.630960
# 116665                               0.062943
# 116666                               0.027737
# 116667                               0.474261
# 116668                               0.122239
#
#         H3K27ac.ENCFF232RQF.bam.readCount  ...  isPromoterElement  \
# 0                                       2  ...              False
# 1                                      15  ...              False
# 2                                      49  ...              False
# 3                                      53  ...              False
# 4                                     134  ...              False
# ...                                   ...  ...                ...
# 116664                                 40  ...              False
# 116665                                 18  ...              False
# 116666                                  1  ...              False
# 116667                                 19  ...              False
# 116668                                 11  ...              False
#
#         isGenicElement  isIntergenicElement  promoterSymbol  genicSymbol  \
# 0                False                 True             NaN          NaN
# 1                False                 True             NaN          NaN
# 2                False                 True             NaN          NaN
# 3                False                 True             NaN          NaN
# 4                False                 True             NaN          NaN
# ...                ...                  ...             ...          ...
# 116664           False                 True             NaN          NaN
# 116665           False                 True             NaN          NaN
# 116666           False                 True             NaN          NaN
# 116667           False                 True             NaN          NaN
# 116668           False                 True             NaN          NaN
#
#                                      name  normalized_h3K27ac  normalized_dhs  \
# 0           intergenic|chr1:585952-586452            0.009428        0.822757
# 1           intergenic|chr1:605341-605841            0.258171        0.490607
# 2           intergenic|chr1:629686-630186            0.496834        0.959883
# 3           intergenic|chr1:633778-634278            0.609420        4.074171
# 4           intergenic|chr1:778388-779144            3.939855       17.088968
# ...                                   ...                 ...             ...
# 116664  intergenic|chrY:11329663-11330163            0.506294        1.715601
# 116665  intergenic|chrY:11333773-11334507            0.116095        1.627231
# 116666  intergenic|chrY:11712120-11712620            0.004714        0.417473
# 116667  intergenic|chrY:56849825-56850381            0.381357        0.432709
# 116668  intergenic|chrY:56850826-56851326            0.083097        0.420520
#
#         activity_base  activity_base_no_qnorm
# 0            0.088073                0.088073
# 1            0.355894                0.355894
# 2            0.690581                0.690581
# 3            1.575716                1.575716
# 4            8.205368                8.205368
# ...               ...                     ...
# 116664       0.931987                0.931987
# 116665       0.434642                0.434642
# 116666       0.044362                0.044362
# 116667       0.406223                0.406223
# 116668       0.186933                0.186933
#
# [116669 rows x 47 columns]

# %%
histone_signals_k562 = pd.read_csv('../data/IHEC-ChIP-Seq-Histone-Signals/Enhancer_Combined_K562_Histone_Signals.csv', sep=',')
histone_signals_gm12878 = pd.read_csv('../data/IHEC-ChIP-Seq-Histone-Signals/Enhancer_Combined_GM12878_Histone_Signals.csv', sep=',')
histone_signals_k562
# Out:
#                                   gene_id  covered  H3K27ac.mean  \
# 0           intergenic|chr1:585952-586452      500      0.000000
# 1           intergenic|chr1:605341-605841      500      0.883907
# 2           intergenic|chr1:629686-630186      500      0.000000
# 3           intergenic|chr1:633778-634278      500      0.000000
# 4           intergenic|chr1:778388-779144      756      7.614350
# ...                                   ...      ...           ...
# 116664  intergenic|chrY:11329663-11330163      500      0.000000
# 116665  intergenic|chrY:11333773-11334507      734      0.266555
# 116666  intergenic|chrY:11712120-11712620      500      0.000000
# 116667  intergenic|chrY:56849825-56850381      556      1.055700
# 116668  intergenic|chrY:56850826-56851326      500      0.013811
#
#         H3K27me3.mean  H3K36me3.mean  H3K4me1.mean  H3K4me3.mean  H3K9me3.mean
# 0            0.000000       0.000000      0.000000      0.000000      0.000000
# 1            0.000000       0.000000      2.214580      1.037200      0.118716
# 2            0.414857       0.000000      0.251587      0.244210      0.516884
# 3            0.541511       0.000000      0.223356      0.000000      0.265364
# 4            0.174603       0.185843      1.272530     11.882000      0.245840
# ...               ...            ...           ...           ...           ...
# 116664       0.160427       0.000000      0.000000      2.281950      0.502922
# 116665       0.218565       0.000000      1.598500      0.227501      1.150730
# 116666       0.000000       0.000000      0.000000      0.000000      0.000000
# 116667       0.297649       0.710372      0.034348      1.433290      1.027910
# 116668       0.390207       0.000000      0.498782      2.057900      1.603920
#
# [116669 rows x 8 columns]

# %%
ihec_activity_gm12878
# Out:
#                                   gene_id  covered  H3K27ac.mean  \
# 0             intergenic|chr1:11623-12123      500      0.000000
# 1             intergenic|chr1:29120-29620      500      0.000000
# 2             intergenic|chr1:35831-36331      500      0.000000
# 3             intergenic|chr1:68840-69340      500      0.000000
# 4           intergenic|chr1:140316-140816      500      0.000000
# ...                                   ...      ...           ...
# 134803  intergenic|chrY:56860276-56860776      500      0.000000
# 134804  intergenic|chrY:56870817-56871778      961      0.160206
# 134805  intergenic|chrY:56872679-56873179      500      0.000000
# 134806  intergenic|chrY:56873407-56873907      500      0.000000
# 134807  intergenic|chrY:56879413-56879913      500      0.000000
#
#         H3K27me3.mean  H3K36me3.mean  H3K4me1.mean  H3K4me3.mean  \
# 0            0.000000       0.000000      0.000000      0.000000
# 1            0.000000       0.000000      0.000000      0.000000
# 2            0.000000       0.000000      0.000000      0.000000
# 3            0.000000       0.000000      0.000000      0.000000
# 4            0.000000       0.000000      0.000000      0.000000
# ...               ...            ...           ...           ...
# 134803       0.657045       0.080214      0.175633      0.719677
# 134804       0.368523       0.434573      0.175640      0.951580
# 134805       0.203334       0.000000      0.072928      0.915007
# 134806       0.435529       0.197384      0.071402      1.158640
# 134807       0.359757       0.089866      0.013156      0.881161
#
#         H3K9me3.mean                               name  activity_base
# 0           0.000000        intergenic|chr1:11623-12123       0.000000
# 1           0.000000        intergenic|chr1:29120-29620       0.000000
# 2           0.000000        intergenic|chr1:35831-36331       0.000000
# 3           0.000000        intergenic|chr1:68840-69340       0.000000
# 4           0.000000      intergenic|chr1:140316-140816       0.000000
# ...              ...                                ...            ...
# 134803      0.233260  intergenic|chrY:56860276-56860776       0.229089
# 134804      1.039640  intergenic|chrY:56870817-56871778       0.215821
# 134805      0.173332  intergenic|chrY:56872679-56873179       0.122665
# 134806      0.342556  intergenic|chrY:56873407-56873907       0.149220
# 134807      0.545197  intergenic|chrY:56879413-56879913       0.153721
#
# [134808 rows x 10 columns]

# %%
ihec_activity_gm12878 = histone_signals_gm12878.merge(orig_activity_gm12878[['name', 'activity_base']], left_on='gene_id', right_on='name', how='left')
ihec_activity_gm12878 = ihec_activity_gm12878[['gene_id','H3K27ac.mean', 'activity_base']]
ihec_activity_k562 = histone_signals_k562.merge(orig_activity_k562[['name', 'activity_base']], left_on='gene_id', right_on='name', how='left')
ihec_activity_k562 = ihec_activity_k562[['gene_id', 'H3K27ac.mean', 'activity_base']]

ihec_activity_k562
# Out:
#                                   gene_id  H3K27ac.mean  activity_base
# 0           intergenic|chr1:585952-586452      0.000000       0.088073
# 1           intergenic|chr1:605341-605841      0.883907       0.355894
# 2           intergenic|chr1:629686-630186      0.000000       0.690581
# 3           intergenic|chr1:633778-634278      0.000000       1.575716
# 4           intergenic|chr1:778388-779144      7.614350       8.205368
# ...                                   ...           ...            ...
# 116664  intergenic|chrY:11329663-11330163      0.000000       0.931987
# 116665  intergenic|chrY:11333773-11334507      0.266555       0.434642
# 116666  intergenic|chrY:11712120-11712620      0.000000       0.044362
# 116667  intergenic|chrY:56849825-56850381      1.055700       0.406223
# 116668  intergenic|chrY:56850826-56851326      0.013811       0.186933
#
# [116669 rows x 3 columns]

# %%
ihec_activity_k562 = ihec_activity_k562.rename(columns={'activity_base': 'H3K27ac.RPM.TSS1Kb', 'H3K27ac.mean': 'mean'})
ihec_activity_gm12878 = ihec_activity_gm12878.rename(columns={'activity_base': 'H3K27ac.RPM.TSS1Kb', 'H3K27ac.mean': 'mean'})

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 6), sharey=True)
plot_promoter_activity_correlation(ihec_activity_k562, 'K562 Promoter Activity Correlation', ax1)
plot_promoter_activity_correlation(ihec_activity_gm12878, 'GM12878 Promoter Activity Correlation', ax2)
plt.tight_layout()
plt.show()

# %%
histone_signals_k562_melted = histone_signals_k562.melt(id_vars=['gene_id', 'covered'], var_name='histone_type', value_name='signal')
histone_signals_gm12878_melted = histone_signals_gm12878.melt(id_vars=['gene_id', 'covered'], var_name='histone_type', value_name='signal')
histone_signals_k562_melted['cell_type'] = 'K562'
histone_signals_gm12878_melted['cell_type'] = 'GM12878'
histone_signals_melted_combined = pd.concat([histone_signals_k562_melted, histone_signals_gm12878_melted], ignore_index=True)
histone_signals_melted_combined
# Out:
#                                    gene_id  covered  histone_type    signal  \
# 0            intergenic|chr1:585952-586452      500  H3K27ac.mean  0.000000
# 1            intergenic|chr1:605341-605841      500  H3K27ac.mean  0.883907
# 2            intergenic|chr1:629686-630186      500  H3K27ac.mean  0.000000
# 3            intergenic|chr1:633778-634278      500  H3K27ac.mean  0.000000
# 4            intergenic|chr1:778388-779144      756  H3K27ac.mean  7.614350
# ...                                    ...      ...           ...       ...
# 1508857  intergenic|chrY:56860276-56860776      500  H3K9me3.mean  0.233260
# 1508858  intergenic|chrY:56870817-56871778      961  H3K9me3.mean  1.039640
# 1508859  intergenic|chrY:56872679-56873179      500  H3K9me3.mean  0.173332
# 1508860  intergenic|chrY:56873407-56873907      500  H3K9me3.mean  0.342556
# 1508861  intergenic|chrY:56879413-56879913      500  H3K9me3.mean  0.545197
#
#         cell_type
# 0            K562
# 1            K562
# 2            K562
# 3            K562
# 4            K562
# ...           ...
# 1508857   GM12878
# 1508858   GM12878
# 1508859   GM12878
# 1508860   GM12878
# 1508861   GM12878
#
# [1508862 rows x 5 columns]

# %%
# plot box plots for each histone type
plt.figure(figsize=(12, 6))
sns.boxplot(data=histone_signals_melted_combined, x='histone_type', y='signal', log_scale=True, hue='cell_type')
plt.xticks(rotation=0)
plt.title('Histone Signals for events by Type')
plt.xlabel('Histone Type')
plt.ylabel('Signal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Event activity

# %%
histone_signals_k562 = pd.read_csv('data/IHEC-ChIP-Seq-Histone-Signals/Events_Combined_K562_Histone_Signals.csv', sep=',')
histone_signals_gm12878 = pd.read_csv('data/IHEC-ChIP-Seq-Histone-Signals/Events_Combined_GM12878_Histone_Signals.csv', sep=',')
histone_signals_k562
# Out:
#                                                  gene_id  covered  \
# 0      intron1|ENSG00000224051;SE:chr1:1325102-132683...     1024
# 1      exon|ENSG00000224051;SE:chr1:1325102-1326836:1...      196
# 2      intron2|ENSG00000224051;SE:chr1:1325102-132683...      209
# 3      intron1|ENSG00000160072;SE:chr1:1486668-148786...     1024
# 4      exon|ENSG00000160072;SE:chr1:1486668-1487863:1...       51
# ...                                                  ...      ...
# 74848  exon|ENSG00000196433;AR:chrY:1624398-1627703:1...       68
# 74849  intron2|ENSG00000196433;AR:chrY:1624398-162770...     1024
# 74850  intron1|ENSG00000197976;AR:chrY:1595532-159919...     1024
# 74851  exon|ENSG00000197976;AR:chrY:1595532-1599192:1...      240
# 74852  intron2|ENSG00000197976;AR:chrY:1595532-159919...      706
#
#        H3K27ac.mean  H3K27me3.mean  H3K36me3.mean  H3K4me1.mean  H3K4me3.mean  \
# 0          2.077580       0.495509        1.04915      12.01370      2.487770
# 1          1.449600       0.994073        3.08687       5.12244      1.032610
# 2          0.816318       0.781234        1.46794       7.26510      1.054710
# 3          0.000000       0.350202        2.01366       1.56203      0.209288
# 4          0.000000       1.368630        2.60509       2.62132      0.458180
# ...             ...            ...            ...           ...           ...
# 74848      0.000000       0.000000        0.00000       0.00000      0.000000
# 74849      0.000000       0.000000        0.00000       0.00000      0.000000
# 74850      0.000000       0.000000        0.00000       0.00000      0.000000
# 74851      0.000000       0.000000        0.00000       0.00000      0.000000
# 74852      0.000000       0.000000        0.00000       0.00000      0.000000
#
#        H3K9me3.mean
# 0          0.403888
# 1          0.549963
# 2          0.545655
# 3          0.540433
# 4          0.000000
# ...             ...
# 74848      0.000000
# 74849      0.000000
# 74850      0.000000
# 74851      0.000000
# 74852      0.000000
#
# [74853 rows x 8 columns]

# %%
# melt and combine the dataframes
histone_signals_k562_melted = histone_signals_k562.melt(id_vars=['gene_id', 'covered'], var_name='histone_type', value_name='signal')
histone_signals_gm12878_melted = histone_signals_gm12878.melt(id_vars=['gene_id', 'covered'], var_name='histone_type', value_name='signal')
histone_signals_k562_melted['cell_type'] = 'K562'
histone_signals_gm12878_melted['cell_type'] = 'GM12878'
histone_signals_melted_combined = pd.concat([histone_signals_k562_melted, histone_signals_gm12878_melted], ignore_index=True)
histone_signals_melted_combined
# Out:
#                                                   gene_id  covered  \
# 0       intron1|ENSG00000224051;SE:chr1:1325102-132683...     1024
# 1       exon|ENSG00000224051;SE:chr1:1325102-1326836:1...      196
# 2       intron2|ENSG00000224051;SE:chr1:1325102-132683...      209
# 3       intron1|ENSG00000160072;SE:chr1:1486668-148786...     1024
# 4       exon|ENSG00000160072;SE:chr1:1486668-1487863:1...       51
# ...                                                   ...      ...
# 898231  exon|ENSG00000196433;AR:chrY:1624398-1627703:1...       68
# 898232  intron2|ENSG00000196433;AR:chrY:1624398-162770...     1024
# 898233  intron1|ENSG00000197976;AR:chrY:1595532-159919...     1024
# 898234  exon|ENSG00000197976;AR:chrY:1595532-1599192:1...      240
# 898235  intron2|ENSG00000197976;AR:chrY:1595532-159919...      706
#
#         histone_type    signal cell_type
# 0       H3K27ac.mean  2.077580      K562
# 1       H3K27ac.mean  1.449600      K562
# 2       H3K27ac.mean  0.816318      K562
# 3       H3K27ac.mean  0.000000      K562
# 4       H3K27ac.mean  0.000000      K562
# ...              ...       ...       ...
# 898231  H3K9me3.mean  0.000000   GM12878
# 898232  H3K9me3.mean  0.000000   GM12878
# 898233  H3K9me3.mean  0.000000   GM12878
# 898234  H3K9me3.mean  0.000000   GM12878
# 898235  H3K9me3.mean  0.000000   GM12878
#
# [898236 rows x 5 columns]

# %%
# plot box plots for each histone type
plt.figure(figsize=(12, 6))
sns.boxplot(data=histone_signals_melted_combined, x='histone_type', y='signal', log_scale=True, hue='cell_type')
plt.xticks(rotation=0)
plt.title('Histone Signals for events by Type')
plt.xlabel('Histone Type')
plt.ylabel('Signal')
plt.tight_layout()
plt.show()
