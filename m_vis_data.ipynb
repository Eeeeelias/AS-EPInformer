# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
psi_response = pd.read_csv('data/psi_response.csv')
psi_response
# Out:
#                                                 event_id          gene_id  \
# 0      ENSG00000224051;SE:chr1:1325102-1326836:132703...  ENSG00000224051
# 1      ENSG00000160072;SE:chr1:1486668-1487863:148791...  ENSG00000160072
# 2      ENSG00000160072;SE:chr1:1489274-1489692:148981...  ENSG00000160072
# 3      ENSG00000197530;SE:chr1:1624901-1624991:162518...  ENSG00000197530
# 4      ENSG00000197530;SE:chr1:1625653-1626650:162675...  ENSG00000197530
# ...                                                  ...              ...
# 24946  ENSG00000259207;AR:chr17:47284695-47286260:472...  ENSG00000259207
# 24947  ENSG00000259207;AR:chr17:47290274-47290954:472...  ENSG00000259207
# 24948  ENSG00000259207;AR:chr17:47291088-47292139:472...  ENSG00000259207
# 24949  ENSG00000259305;AR:chr8:123231757-123237798:12...  ENSG00000259305
# 24950  ENSG00000259511;AR:chr15:84172585-84174008:841...  ENSG00000259511
#
#        K562_summed_tpm  GM12878_summed_tpm  K562_alt_tpm  GM12878_alt_tpm  \
# 0             0.499687            1.133219      0.492760         1.120903
# 1             1.236285            1.539202      1.172019         1.475816
# 2             1.172019            1.475816      0.611723         0.610660
# 3             0.220108            0.382017      0.184691         0.359835
# 4             0.089905            0.120574      0.064458         0.089905
# ...                ...                 ...           ...              ...
# 24946         0.201397            1.089905     -1.000000        -1.000000
# 24947         0.120574            1.070407     -1.000000        -1.000000
# 24948         0.120574            1.070407     -1.000000        -1.000000
# 24949         0.733197            0.445604     -1.000000        -1.000000
# 24950         0.269513           -0.886057     -1.000000        -1.000000
#
#        K562_gene_level_tpm  GM12878_gene_level_tpm  K562_SE_psi  \
# 0                 0.576341                1.146438     0.983660
# 1                 1.344589                1.576687     0.861646
# 2                 1.344589                1.576687     0.270325
# 3                 0.833147                1.226858     0.916667
# 4                 0.833147                1.226858     0.938053
# ...                    ...                     ...          ...
# 24946             0.201397                1.089905     1.000000
# 24947             0.201397                1.089905     1.000000
# 24948             0.201397                1.089905     1.000000
# 24949             0.744293                0.460898     1.000000
# 24950             0.413300               -0.619789     1.000000
#
#        GM12878_SE_psi
# 0            0.971831
# 1            0.863808
# 2            0.133512
# 3            0.948052
# 4            0.926230
# ...               ...
# 24946        1.000000
# 24947        1.000000
# 24948        1.000000
# 24949        1.000000
# 24950        1.000000
#
# [24951 rows x 10 columns]

# %%
# plot distribution of K562_SE_psi
plt.figure(figsize=(10, 6))
sns.histplot(psi_response[psi_response['event_id'].str.contains(';SE:')]['K562_SE_psi'], bins=30, kde=True)
plt.title('Distribution of K562_SE_psi')
plt.xlabel('K562_SE_psi')
plt.ylabel('Frequency')
plt.grid()
plt.show()
